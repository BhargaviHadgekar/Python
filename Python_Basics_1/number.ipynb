# %%
l1 = [1,2,3,4,5]

# %%
l1.append(6)
l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1.remove(3)
l1
# Out:
# [1, 2, 4, 5, 6]

# %%
l1
# Out:
# [1, 2, 4, 5, 6]

# %%
l1.append(3)
l1
# Out:
# [1, 2, 4, 5, 6, 3, 3, 3, 3]

# %%
l1.remove(3)
l1
# Out:
# [1, 2, 4, 5, 6, 3]

# %%
l1[1]=3

# %%
l1
# Out:
# [1, 3, 4, 5, 6, 3]
