# %%
'hello World'
# Out:
# 'hello World'

# %%
s = 'abcdefghijklmnopqrstuvwxyz'

# %%
s
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
s[5]
# Out:
# 'f'

# %%
s[-1]
# Out:
# 'z'

# %%
s[::-1]
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %%
s[10:15]
# Out:
# 'klmno'

# %%
s[-6:-20:-1]
# Out:
# 'utsrqponmlkjih'

# %%
s1='Hello World from Python'
s1
# Out:
# 'Hello World from Python'

# %%
# .split() - Splits the string at the specified separator, and returns a list
s1.split()
# Out:
# ['Hello', 'World', 'from', 'Python']

# %%
# .capitalize() - Converts the first character to upper case
s.capitalize()
# Out:
# 'Abcdefghijklmnopqrstuvwxyz'

# %%
# .casefold() - Converts string into lower case
s1.casefold()
# Out:
# 'hello world from python'

# %%
# .center() - Returns a centered string
s1.center(50)
# Out:
# '             Hello World from Python              '

# %%
# .count() - Returns the number of times a specified value occurs in a string
s1.count('o')
# Out:
# 4

# %%
# .encode() - Returns an encoded version of the string
s1.encode()
# Out:
# b'Hello World from Python'

# %%
# .endswith() - Returns true if the string ends with the specified value
s1.endswith('p')
# Out:
# False

# %%
s1.endswith('H')
# Out:
# False

# %%
s1.endswith('n')
# Out:
# True

# %%
# .expandtabs() - Sets the tab size of the string
str2 = "Id\tName\tAge\tE-mail"
str2
# Out:
# 'Id\tName\tAge\tE-mail'

# %%
str2.expandtabs(10)
# Out:
# 'Id        Name      Age       E-mail'

# %%
str3="Id\tName\tAge\tE-mail\n1\tBhargavi\t21\tbhargavi@gmail.com\n2\tJohn\t22\tjohn@gmail.com"

# %%
print(str3.expandtabs(15))
# Out:
# Id             Name           Age            E-mail
# 1              Bhargavi       21             bhargavi@gmail.com
# 2              John           22             john@gmail.com

# %%
s1
# Out:
# 'Hello World from Python'

# %%
# .find() - Searches the string for a specified value and returns the position of where it was found
s1.find('o')
# Out:
# 4

# %%
s1.find('P')
# Out:
# 17

# %%
# returns -1 if the value is not found
s1.find('z')
# Out:
# -1

# %%
# .format() - Formats specified values in a string
s1.format()
# Out:
# 'Hello World from Python'

# %%
# .format_map() - Formats specified values in a string using a dictionary
str2.format_map({'Id':'3','Name':'Alice','Age':'23','E-mail':'alice@example.com'})
# Out:
# 'Id\tName\tAge\tE-mail'

# %%
# .index() - Searches the string for a specified value and returns the position of where it was found
s1.index('H')
# Out:
# 0

# %%
# .isalnum() - Returns True if all characters in the string are alphanumeric
s1.isalnum()
# Out:
# False

# %%
# .isascii() - Returns True if all characters in the string are ascii characters
s1.isascii()
# Out:
# True

# %%
# .isalpha() - Returns True if all characters in the string are in the alphabet
s1.isalpha()
# Out:
# False

# %%
# .isdecimal() - Returns True if all characters in the string are decimals
s1.isdecimal()
# Out:
# False

# %%
# .isdigit() - Returns True if all characters in the string are digits
s1.isdigit()
# Out:
# False

# %%
# .isidentifier() - Returns True if the string is an identifier
s1.isidentifier()
# Out:
# False

# %%
# .islower() - Returns True if all characters in the string are lower case
s1.islower()
# Out:
# False

# %%
# .isnumeric() - Returns True if all characters in the string are numeric
s1.isnumeric()
# Out:
# False

# %%
# .isprintable() - Returns True if all characters in the string are printable
s1.isprintable()
# Out:
# True

# %%
# .isspace() - Returns True if all characters in the string are whitespaces
s1.isspace()
# Out:
# False

# %%
# .istitle() - Returns True if the string is a title cased string
s1.istitle()
# Out:
# False

# %%
s1.join([' -hello world ', ' my', ' name bhargavi'])
# Out:
# ' -hello world Hello World from Python myHello World from Python name bhargavi'

# %%
s1.ljust(50)
# Out:
# 'Hello World from Python                           '

# %%
s1.lower()
# Out:
# 'hello world from python'

# %%
s1.lower()
# Out:
# 'hello world from python'

# %%
# Arithmetic operations
a = 10
b = 3

addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b

print(f"Addition: {a} + {b} = {addition}")
print(f"Subtraction: {a} - {b} = {subtraction}")
print(f"Multiplication: {a} * {b} = {multiplication}")
print(f"Division: {a} / {b} = {division}")
# Out:
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335

# %%
# Create a list with various data types
my_list = [1, 2, 3, 4, 5, 'Hello', 3.14, True]

# Display the list
print("Original list:", my_list)

# List operations
print("First element:", my_list[0])
print("Last element:", my_list[-1])
print("Length of list:", len(my_list))

# List methods
my_list.append(100)
print("After append:", my_list)

my_list.extend([6, 7, 8])
print("After extend:", my_list)

my_list.insert(2, 'inserted')
print("After insert:", my_list)

my_list.remove('inserted')
print("After remove:", my_list)

print("Index of 'Hello':", my_list.index('Hello'))
print("Count of 5:", my_list.count(5))
# Out:
# Original list: [1, 2, 3, 4, 5, 'Hello', 3.14, True]
# First element: 1
# Last element: True
# Length of list: 8
# After append: [1, 2, 3, 4, 5, 'Hello', 3.14, True, 100]
# After extend: [1, 2, 3, 4, 5, 'Hello', 3.14, True, 100, 6, 7, 8]
# After insert: [1, 2, 'inserted', 3, 4, 5, 'Hello', 3.14, True, 100, 6, 7, 8]
# After remove: [1, 2, 3, 4, 5, 'Hello', 3.14, True, 100, 6, 7, 8]
# Index of 'Hello': 5
# Count of 5: 1

# %%
s1.upper()
# Out:
# 'HELLO WORLD FROM PYTHON'
